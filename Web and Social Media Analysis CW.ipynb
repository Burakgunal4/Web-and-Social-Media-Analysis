# %% [markdown]
# <a href="https://colab.research.google.com/github/Burakgunal4/Web-and-Social-Media-Analysis/blob/main/Web%20and%20Social%20Media%20Analysis%20CW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
from googleapiclient.discovery import build
import pandas as pd

# Insert your YouTube Data API key here
api_key = "AIzaSyC0dslUAMHingkwPs7AEdRkiHV9SrFLzew"
video_id = "wgVOgGLtPtc"  # ID of the selected NBA video

# Initialize YouTube API client
youtube = build('youtube', 'v3', developerKey=api_key)

# Create a list to store comments
comments = []
next_page_token = None  # For paginating through multiple pages

# Continue retrieving comments until we have 200
while len(comments) < 200:
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100,  # Maximum comments per page is 100
        textFormat="plainText",
        pageToken=next_page_token
    )
    response = request.execute()

    # Extract comment text and like count
    for item in response["items"]:
        comment_snippet = item["snippet"]["topLevelComment"]["snippet"]
        text = comment_snippet["textDisplay"]
        like_count = comment_snippet.get("likeCount", 0)  # If likeCount is missing, use 0
        comments.append({"comment": text, "likes": like_count})

        # Stop if 200 comments have been collected
        if len(comments) >= 200:
            break

    # Update token for next page
    next_page_token = response.get("nextPageToken")

# Convert to a pandas DataFrame
df = pd.DataFrame(comments)

# Sort comments by like count in descending order and get the top 10
top_comments = df.sort_values(by="likes", ascending=False).head(10)

# Reset index and display
top_comments.reset_index(drop=True, inplace=True)
top_comments
# Out:
#                                              comment  likes
# 0                               Who’s in March 2025?    186
# 1                                       March 2025 ?      6
# 2  To watch that LeBron block live was like a spi...      4
# 3  I remember watching this live and busting as s...      4
# 4  This is probably the greatest NBA title victor...      4
# 5  This was the day LeBron became my favorite player      4
# 6  that’s why he’s the goat. He’s the goat, and h...      3
# 7  I don't think many will realize what LBJ did h...      3
# 8                      watching on my lunch break rn      3
# 9  Lebron stats this whole video \n0-2 fg\n0 assi...      3

# %%
# Import necessary libraries
from googleapiclient.discovery import build
import pandas as pd

# Insert your YouTube Data API key here
api_key = "AIzaSyC0dslUAMHingkwPs7AEdRkiHV9SrFLzew"
video_id = "wgVOgGLtPtc"  # ID of the selected NBA video

# Initialize YouTube API client
youtube = build('youtube', 'v3', developerKey=api_key)

# Create a list to store comments
comments = []
next_page_token = None  # For paginating through multiple pages

# Continue retrieving comments until we have 200
while len(comments) < 200:
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100,  # Maximum comments per page is 100
        textFormat="plainText",
        pageToken=next_page_token
    )
    response = request.execute()

    # Extract comment text and like count
    for item in response["items"]:
        comment_snippet = item["snippet"]["topLevelComment"]["snippet"]
        text = comment_snippet["textDisplay"]
        like_count = comment_snippet.get("likeCount", 0)  # If likeCount is missing, use 0
        comments.append({"comment": text, "likes": like_count})

        # Stop if 200 comments have been collected
        if len(comments) >= 200:
            break

    # Update token for next page
    next_page_token = response.get("nextPageToken")

# Convert to a pandas DataFrame
df = pd.DataFrame(comments)

# Sort comments by like count in descending order and get the top 10
top_comments = df.sort_values(by="likes", ascending=False).head(10)

# Reset index and display
top_comments.reset_index(drop=True, inplace=True)
top_comments
# Out:
#                                              comment  likes
# 0                               Who’s in March 2025?    186
# 1                                       March 2025 ?      6
# 2  To watch that LeBron block live was like a spi...      4
# 3  I remember watching this live and busting as s...      4
# 4  This is probably the greatest NBA title victor...      4
# 5  This was the day LeBron became my favorite player      4
# 6  that’s why he’s the goat. He’s the goat, and h...      3
# 7  I don't think many will realize what LBJ did h...      3
# 8                      watching on my lunch break rn      3
# 9  Lebron stats this whole video \n0-2 fg\n0 assi...      3

# %%
# Import necessary libraries
from googleapiclient.discovery import build
import pandas as pd

# Insert your YouTube Data API key here
api_key = "AIzaSyC0dslUAMHingkwPs7AEdRkiHV9SrFLzew"
video_id = "wgVOgGLtPtc"  # ID of the selected NBA video

# Initialize YouTube API client
youtube = build('youtube', 'v3', developerKey=api_key)

# Create a list to store comments
comments = []
next_page_token = None  # For paginating through multiple pages

# Continue retrieving comments until we have 200
while len(comments) < 200:
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100,  # Maximum comments per page is 100
        textFormat="plainText",
        pageToken=next_page_token
    )
    response = request.execute()

    # Extract comment text and like count
    for item in response["items"]:
        comment_snippet = item["snippet"]["topLevelComment"]["snippet"]
        text = comment_snippet["textDisplay"]
        like_count = comment_snippet.get("likeCount", 0)  # If likeCount is missing, use 0
        comments.append({"comment": text, "likes": like_count})

        # Stop if 200 comments have been collected
        if len(comments) >= 200:
            break

    # Update token for next page
    next_page_token = response.get("nextPageToken")

# Convert to a pandas DataFrame
df = pd.DataFrame(comments)

# Sort comments by like count in descending order and get the top 10
top_comments = df.sort_values(by="likes", ascending=False).head(10)

# Reset index and display
top_comments.reset_index(drop=True, inplace=True)
top_comments

display(df.head(200))
display(top_comments)
# Out:
#                                                comment  likes
# 0                                          Jesus saves      0
# 1          Most amazing championship in nba history!!💯      0
# 2                            who’s here in april 2025?      0
# 3    At 1:38, shouldn't that have been called a fou...      0
# 4    Regardless of what you think of him as a playe...      0
# ..                                                 ...    ...
# 195  Lebron is the goat if you have any questions j...      0
# 196  I was a lebron hater, but this finals series m...      1
# 197  Was there a foul by iguodala on lbj at that la...      2
# 198  1:38 the hand is part of the ball during shoot...      0
# 199                           i’m going to miss lebron      1
#
# [200 rows x 2 columns]
#                                              comment  likes
# 0                               Who’s in March 2025?    186
# 1                                       March 2025 ?      6
# ...

# %%
# Import necessary libraries
from googleapiclient.discovery import build
import pandas as pd

# Insert your YouTube Data API key here
api_key = "AIzaSyC0dslUAMHingkwPs7AEdRkiHV9SrFLzew"
video_id = "wgVOgGLtPtc"  # ID of the selected NBA video

# Initialize YouTube API client
youtube = build('youtube', 'v3', developerKey=api_key)

# Create a list to store comments
comments = []
next_page_token = None  # For paginating through multiple pages

# Continue retrieving comments until we have 200
while len(comments) < 200:
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100,  # Maximum comments per page is 100
        textFormat="plainText",
        pageToken=next_page_token
    )
    response = request.execute()

    # Extract comment text and like count
    for item in response["items"]:
        comment_snippet = item["snippet"]["topLevelComment"]["snippet"]
        text = comment_snippet["textDisplay"]
        like_count = comment_snippet.get("likeCount", 0)  # If likeCount is missing, use 0
        comments.append({"comment": text, "likes": like_count})

        # Stop if 200 comments have been collected
        if len(comments) >= 200:
            break

    # Update token for next page
    next_page_token = response.get("nextPageToken")

# Convert to a pandas DataFrame
df = pd.DataFrame(comments)

# Sort comments by like count in descending order and get the top 10
top_comments = df.sort_values(by="likes", ascending=False).head(10)

# Reset index and display
top_comments.reset_index(drop=True, inplace=True)
top_comments

display(df.head(200))
display(top_comments)
# Out:
#                                                comment  likes
# 0                                          Jesus saves      0
# 1          Most amazing championship in nba history!!💯      0
# 2                            who’s here in april 2025?      0
# 3    At 1:38, shouldn't that have been called a fou...      0
# 4    Regardless of what you think of him as a playe...      0
# ..                                                 ...    ...
# 195  Lebron is the goat if you have any questions j...      0
# 196  I was a lebron hater, but this finals series m...      1
# 197  Was there a foul by iguodala on lbj at that la...      2
# 198  1:38 the hand is part of the ball during shoot...      0
# 199                           i’m going to miss lebron      1
#
# [200 rows x 2 columns]
#                                              comment  likes
# 0                               Who’s in March 2025?    186
# 1                                       March 2025 ?      6
# ...

# %%
# Import required libraries
import pandas as pd
import string
import nltk
from nltk.corpus import stopwords

# Download stopwords (required for the first run)
nltk.download('stopwords')

# Load English stopwords
stop_words = set(stopwords.words('english'))

# Step 1: Convert all text to lowercase
df['comment_clean'] = df['comment'].str.lower()

# Step 2: Remove punctuation from text
df['comment_clean'] = df['comment_clean'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))

# Step 3: Remove English stopwords
df['comment_clean'] = df['comment_clean'].apply(
    lambda x: ' '.join([word for word in x.split() if word not in stop_words])
)

# Step 4: Remove comments with fewer than 3 words
df_clean = df[df['comment_clean'].str.split().str.len() >= 3]

# Step 5: Remove empty or whitespace-only comments
df_clean = df_clean[df_clean['comment_clean'].str.strip().astype(bool)]

# Preview the first 5 cleaned comments
df_clean.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                              comment  likes  \
# 1        Most amazing championship in nba history!!💯      0
# 2                          who’s here in april 2025?      0
# 3  At 1:38, shouldn't that have been called a fou...      0
# 4  Regardless of what you think of him as a playe...      0
# 5                                  Anyone April 2025      2
#
#                                        comment_clean
# 1                  amazing championship nba history💯
# 2                                   who’s april 2025
# 3  138 shouldnt called foul guarantee way around ...
# 4  regardless think player seeing man reach pinna...
# 5                                  anyone april 2025

# %%
# Import required libraries
import pandas as pd
import string
import nltk
from nltk.corpus import stopwords

# Download stopwords (required for the first run)
nltk.download('stopwords')

# Load English stopwords
stop_words = set(stopwords.words('english'))

# Step 1: Convert all text to lowercase
df['comment_clean'] = df['comment'].str.lower()

# Step 2: Remove punctuation from text
df['comment_clean'] = df['comment_clean'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))

# Step 3: Remove English stopwords
df['comment_clean'] = df['comment_clean'].apply(
    lambda x: ' '.join([word for word in x.split() if word not in stop_words])
)

# Step 4: Remove comments with fewer than 3 words
df_clean = df[df['comment_clean'].str.split().str.len() >= 3]

# Step 5: Remove empty or whitespace-only comments
df_clean = df_clean[df_clean['comment_clean'].str.strip().astype(bool)]

# OPTIONAL Step 6: Reset index for clean DataFrame
df_clean.reset_index(drop=True, inplace=True)

# Step 7: Display all cleaned comments
df_clean  # This will show all cleaned comments in a table
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                comment  likes  \
# 0          Most amazing championship in nba history!!💯      0
# 1                            who’s here in april 2025?      0
# 2    At 1:38, shouldn't that have been called a fou...      0
# 3    Regardless of what you think of him as a playe...      0
# 4                                    Anyone April 2025      2
# ..                                                 ...    ...
# 161  Lebron is the goat if you have any questions j...      0
# 162  I was a lebron hater, but this finals series m...      1
# 163  Was there a foul by iguodala on lbj at that la...      2
# 164  1:38 the hand is part of the ball during shoot...      0
# 165                           i’m going to miss lebron      1
#
#                                          comment_clean
# ...

# %%
# Import required libraries
import pandas as pd
import string
import nltk
from nltk.corpus import stopwords

# Download stopwords (required for the first run)
nltk.download('stopwords')

# Load English stopwords
stop_words = set(stopwords.words('english'))

# Step 1: Convert all text to lowercase
df['comment_clean'] = df['comment'].str.lower()

# Step 2: Remove punctuation from text
df['comment_clean'] = df['comment_clean'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))

# Step 3: Remove English stopwords
df['comment_clean'] = df['comment_clean'].apply(
    lambda x: ' '.join([word for word in x.split() if word not in stop_words])
)

# Step 4: Remove comments with fewer than 3 words
df_clean = df[df['comment_clean'].str.split().str.len() >= 3]

# Step 5: Remove empty or whitespace-only comments
df_clean = df_clean[df_clean['comment_clean'].str.strip().astype(bool)]

# OPTIONAL Step 6: Reset index for clean DataFrame
df_clean.reset_index(drop=True, inplace=True)

# Step 7: Display all cleaned comments
df_clean  # This will show all cleaned comments in a table


df_clean[['comment_clean']]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                          comment_clean
# 0                    amazing championship nba history💯
# 1                                     who’s april 2025
# 2    138 shouldnt called foul guarantee way around ...
# 3    regardless think player seeing man reach pinna...
# 4                                    anyone april 2025
# ..                                                 ...
# 161                  lebron goat questions watch video
# 162  lebron hater finals series made respect boy st...
# 163                            foul iguodala lbj layup
# 164  138 hand part ball shooting dont know announce...
# 165                              i’m going miss lebron
#
# [166 rows x 1 columns]

# %%
# !pip install wordcloud matplotlib

# Import necessary libraries for word cloud and plotting
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine all cleaned comments into a single string for analysis
text = ' '.join(df_clean['comment_clean'])


# Create a WordCloud object using the combined text
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the WordCloud using matplotlib
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide axis
plt.title("Word Cloud of Most Frequent Words in Comments")
plt.show()

# %%
# Preprocessing steps to create df_clean
import pandas as pd
import string
import nltk
from nltk.corpus import stopwords

# Download stopwords (only once)
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Assume you already have 'df' from earlier (with 200 raw comments)
df['comment_clean'] = df['comment'].str.lower()
df['comment_clean'] = df['comment_clean'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))
df['comment_clean'] = df['comment_clean'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))
df_clean = df[df['comment_clean'].str.split().str.len() >= 3]
df_clean = df_clean[df_clean['comment_clean'].str.strip().astype(bool)]
df_clean.reset_index(drop=True, inplace=True)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.DataFrame(comments)  # → tırnaksız olacak

# %%
# Preprocessing steps to create df_clean
import pandas as pd
import string
import nltk
from nltk.corpus import stopwords

# Download stopwords (only once)
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Assume you already have 'df' from earlier (with 200 raw comments)
df['comment_clean'] = df['comment'].str.lower()
df['comment_clean'] = df['comment_clean'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))
df['comment_clean'] = df['comment_clean'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))
df_clean = df[df['comment_clean'].str.split().str.len() >= 3]
df_clean = df_clean[df_clean['comment_clean'].str.strip().astype(bool)]
df_clean.reset_index(drop=True, inplace=True)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# !pip install wordcloud matplotlib

# Import necessary libraries for word cloud and plotting
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine all cleaned comments into a single string for analysis
text = ' '.join(df_clean['comment_clean'])


# Create a WordCloud object using the combined text
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the WordCloud using matplotlib
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide axis
plt.title("Word Cloud of Most Frequent Words in Comments")
plt.show()

# %%
# Import Counter for word counting and pandas for tabular data
from collections import Counter
import pandas as pd

# Count word frequencies in the text
word_counts = Counter(text.split())

# Create a DataFrame of the top 15 most common words
freq_df = pd.DataFrame(word_counts.most_common(15), columns=['word', 'count'])

# Display the frequency table
freq_df
# Out:
#       word  count
# 0   lebron     30
# 1     game     25
# 2     time     22
# 3      nba     16
# 4   finals     16
# 5     back     15
# 6     goat     14
# 7    watch     13
# 8    block     12
# 9    still     11
# 10    cavs     11
# 11   james     10
# 12     get     10
# 13    ever     10
# 14     lbj      9

# %%
# Plot a bar chart using the frequency table
plt.figure(figsize=(10, 6))
plt.bar(freq_df['word'], freq_df['count'], color='skyblue')
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Top 15 Most Frequent Words")
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.tight_layout()  # Adjust layout
plt.show()

# %%
# Install NLTK if not already installed (run only once)
# !pip install nltk

# Import necessary libraries
import nltk
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
import matplotlib.pyplot as plt

# Download tokenizer from NLTK (needed for some setups)
nltk.download('punkt')

# Step 1: Prepare the cleaned comments as a list of strings
text_data = df_clean['comment_clean'].tolist()

# Step 2: Create bigrams using CountVectorizer from sklearn
# ngram_range=(2, 2) means we only want 2-word combinations
vectorizer = CountVectorizer(ngram_range=(2, 2), stop_words='english')
X = vectorizer.fit_transform(text_data)

# Step 3: Count the frequencies of each bigram
bigrams_freq = X.sum(axis=0)
bigrams = [(word, bigrams_freq[0, idx]) for word, idx in vectorizer.vocabulary_.items()]

# Step 4: Sort and take the top 15 most frequent bigrams
bigrams = sorted(bigrams, key=lambda x: x[1], reverse=True)[:15]

# Step 5: Convert the bigrams into a DataFrame for easy visualization
bigram_df = pd.DataFrame(bigrams, columns=['bigram', 'count'])

# Step 6: Plot a horizontal bar chart of the top 15 bigrams
plt.figure(figsize=(12, 6))
plt.barh(bigram_df['bigram'], bigram_df['count'], color='lightgreen')
plt.xlabel("Frequency")
plt.title("Top 15 Most Frequent Bigrams")
plt.gca().invert_yaxis()  # Show highest frequency at the top
plt.tight_layout()
plt.show()
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# REVISED API DATA RETENTION CODE (Time and user information with comments)

from googleapiclient.discovery import build
import pandas as pd

# Set the API key and video ID
api_key = "AIzaSyC0dslUAMHingkwPs7AEdRkiHV9SrFLzew"
video_id = "wgVOgGLtPtc"

# Initialize API client
youtube = build('youtube', 'v3', developerKey=api_key)

# Retrieve comments
comments = []
next_page_token = None

while len(comments) < 200:
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100,
        textFormat="plainText",
        pageToken=next_page_token
    )
    response = request.execute()

    for item in response["items"]:
        snippet = item["snippet"]["topLevelComment"]["snippet"]
        text = snippet["textDisplay"]
        likes = snippet.get("likeCount", 0)
        author = snippet.get("authorDisplayName", "Anonymous")
        published = snippet.get("publishedAt", None)

        comments.append({
            "comment": text,
            "likes": likes,
            "author": author,
            "publishedAt": published
        })

        if len(comments) >= 200:
            break

    next_page_token = response.get("nextPageToken")

# Create DataFrame
df = pd.DataFrame(comments)
print(df.head(200))
# Out:
#                                                comment  likes  \
# 0                                          Jesus saves      0
# 1          Most amazing championship in nba history!!💯      0
# 2                            who’s here in april 2025?      0
# 3    At 1:38, shouldn't that have been called a fou...      0
# 4    Regardless of what you think of him as a playe...      0
# ..                                                 ...    ...
# 195  Lebron is the goat if you have any questions j...      0
# 196  I was a lebron hater, but this finals series m...      1
# 197  Was there a foul by iguodala on lbj at that la...      2
# 198  1:38 the hand is part of the ball during shoot...      0
# 199                           i’m going to miss lebron      1
#
#                      author           publishedAt
# 0           @sethcreech1014  2025-04-05T14:48:09Z
# 1               @peewee3030  2025-04-05T10:56:17Z
# 2               @aliyahmoss  2025-04-05T05:38:05Z
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 2: Convert the 'publishedAt' column to datetime format
df['publishedAt'] = pd.to_datetime(df['publishedAt'])

# Step 3: Extract only the date part (exclude time)
df['date_only'] = df['publishedAt'].dt.date

# Step 4: Count number of comments for each date
comments_by_day = df.groupby('date_only').size()

# Step 5: Plot a time-series line graph of daily comment counts
plt.figure(figsize=(10, 5))
comments_by_day.plot(kind='line', marker='o', color='purple')
plt.title("Number of Comments Over Time")
plt.xlabel("Date")
plt.ylabel("Number of Comments")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
## Create Top Users Table

# Count number of comments per user and select top 10
user_counts = df['author'].value_counts().head(10)

# Display the user comment counts
user_counts
# Out:
# author
# @martonhorvath482       3
# @zacharywagner1708      3
# @無印良心                   3
# @danielmurray-i4h       2
# @martaviuslucado7320    2
# @gregslav6755           2
# @darpress9086           2
# @yaelohang13            2
# @Hooper.DaGoat          2
# @Shalo-z9u8x            2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Plot a bar chart of the most active users
plt.figure(figsize=(10, 5))
user_counts.plot(kind='bar', color='orange')
plt.title("Top 10 Most Active Users")
plt.xlabel("Username")
plt.ylabel("Number of Comments")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-23-58afa9c92ade>:10: UserWarning: Glyph 28961 (\N{CJK UNIFIED IDEOGRAPH-7121}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-23-58afa9c92ade>:10: UserWarning: Glyph 21360 (\N{CJK UNIFIED IDEOGRAPH-5370}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-23-58afa9c92ade>:10: UserWarning: Glyph 33391 (\N{CJK UNIFIED IDEOGRAPH-826F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-23-58afa9c92ade>:10: UserWarning: Glyph 24515 (\N{CJK UNIFIED IDEOGRAPH-5FC3}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 28961 (\N{CJK UNIFIED IDEOGRAPH-7121}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21360 (\N{CJK UNIFIED IDEOGRAPH-5370}) missing from font(s) DejaVu Sans.
# ...

# %%
# Install nltk
# !pip install nltk

# Import necessary libraries
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Download VADER lexicon (only required once)
nltk.download('vader_lexicon')

# Initialize VADER sentiment analyzer
vader = SentimentIntensityAnalyzer()
# Out:
# ...
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Apply VADER sentiment scoring to each comment
def get_sentiment_label(score):
    if score >= 0.05:
        return 'Positive'
    elif score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

# Calculate sentiment scores and assign labels
df['compound_score'] = df['comment'].apply(lambda x: vader.polarity_scores(x)['compound'])
df['sentiment'] = df['compound_score'].apply(get_sentiment_label)

# Display a sample of results
df[['comment', 'compound_score', 'sentiment']].head(200)
# Out:
#                                                comment  compound_score  \
# 0                                          Jesus saves          0.0000
# 1          Most amazing championship in nba history!!💯          0.8341
# 2                            who’s here in april 2025?          0.0000
# 3    At 1:38, shouldn't that have been called a fou...          0.2500
# 4    Regardless of what you think of him as a playe...          0.7096
# ..                                                 ...             ...
# 195  Lebron is the goat if you have any questions j...          0.0000
# 196  I was a lebron hater, but this finals series m...          0.5113
# 197  Was there a foul by iguodala on lbj at that la...          0.0000
# 198  1:38 the hand is part of the ball during shoot...          0.8221
# 199                           i’m going to miss lebron         -0.1531
#
#     sentiment
# 0     Neutral
# 1    Positive
# 2     Neutral
# 3    Positive
# 4    Positive
# ..        ...
# ...

# %%
# Count the number of each sentiment label
sentiment_counts = df['sentiment'].value_counts()

# Convert counts to percentages
sentiment_percentages = sentiment_counts / sentiment_counts.sum() * 100

# Display the result
sentiment_percentages
# Out:
# sentiment
# Neutral     41.0
# Positive    40.5
# Negative    18.5
# Name: count, dtype: float64

# %%
import matplotlib.pyplot as plt

# Pie chart of sentiment distribution
plt.figure(figsize=(6, 6))
plt.pie(sentiment_percentages, labels=sentiment_percentages.index, autopct='%1.1f%%', colors=['green', 'grey', 'red'])
plt.title("Sentiment Distribution (Pie Chart)")
plt.show()

# %%
# Install necessary libraries
# !pip install gensim nltk

# Import libraries
import gensim
from gensim import corpora
import nltk
from nltk.corpus import stopwords

# Download stopwords (if not downloaded before)
nltk.download('stopwords')

# Load English stopwords
stop_words = stopwords.words('english')
# Out:
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Comment cleaning steps (if not already re-run)
import pandas as pd
import string
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

# Assuming df is already defined (raw comments)
df['comment_clean'] = df['comment'].str.lower()
df['comment_clean'] = df['comment_clean'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))
df['comment_clean'] = df['comment_clean'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))
df_clean = df[df['comment_clean'].str.split().str.len() >= 3]
df_clean = df_clean[df_clean['comment_clean'].str.strip().astype(bool)]
df_clean.reset_index(drop=True, inplace=True)

# %%
# Tokenize and clean each comment
texts = [
    [word for word in comment.split() if word not in stop_words]
    for comment in df_clean['comment_clean']
]

# %%
# Create dictionary and corpus
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
# Build the LDA model (you can adjust num_topics)
lda_model = gensim.models.ldamodel.LdaModel(
    corpus=corpus,
    id2word=dictionary,
    num_topics=5,  # Number of the main topics
    random_state=42,
    passes=10,
    per_word_topics=True
)

# %%
# Display the top words in each topic
topics = lda_model.print_topics(num_words=5)
for idx, topic in topics:
    print(f"Topic {idx+1}: {topic}")
# Out:
# Topic 1: 0.019*"back" + 0.012*"lebron" + 0.012*"time" + 0.012*"watching" + 0.012*"2025"
# Topic 2: 0.019*"lebron" + 0.018*"time" + 0.018*"game" + 0.015*"goat" + 0.013*"finals"
# Topic 3: 0.016*"game" + 0.013*"james" + 0.011*"foul" + 0.011*"get" + 0.011*"lebron"
# Topic 4: 0.015*"lebron" + 0.015*"finals" + 0.009*"ever" + 0.009*"would" + 0.009*"year"
# Topic 5: 0.015*"it’s" + 0.013*"watch" + 0.010*"years" + 0.010*"time" + 0.008*"remember"

# %%
# Display the top words in each topic
topics = lda_model.show_topics(num_topics=5, num_words=5, formatted=False)

for i, topic in topics:
    keywords = ", ".join([word for word, prob in topic])
    print(f"Topic {i+1}: {keywords}")
# Out:
# Topic 1: back, lebron, time, watching, 2025
# Topic 2: lebron, time, game, goat, finals
# Topic 3: game, james, foul, get, lebron
# Topic 4: lebron, finals, ever, would, year
# Topic 5: it’s, watch, years, time, remember

# %%
import matplotlib.pyplot as plt

# Number of topics and words per topic
num_topics = 5
topn = 5

# Set up subplots
fig, axes = plt.subplots(nrows=1, ncols=num_topics, figsize=(18, 5), sharey=True)

# Loop through topics
for i in range(num_topics):
    topic = lda_model.show_topic(i, topn=topn)
    words = [word for word, prob in topic]
    weights = [prob for word, prob in topic]

    axes[i].bar(words, weights, color='skyblue')
    axes[i].set_title(f"Topic {i+1}")
    axes[i].tick_params(axis='x', rotation=45)
    axes[i].set_ylim(0, max(weights)*1.2)  # uniform y-scale

fig.suptitle("Top 5 Keywords in Each Topic", fontsize=16)
plt.tight_layout()
plt.subplots_adjust(top=0.85)  # add spacing for suptitle
plt.show()

# %%
# Import necessary libraries
from googleapiclient.discovery import build
import pandas as pd

# Set your API key and video ID
api_key = "AIzaSyDzSVpL-QoowybkhRGgeyfhkbga95bq88o"
video_id = "AFC5RaH4xMg"  # second video ID

# Initialize API client
youtube = build('youtube', 'v3', developerKey=api_key)

# Retrieve comments
comments = []
next_page_token = None

while len(comments) < 400:
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100,
        textFormat="plainText",
        pageToken=next_page_token
    )
    response = request.execute()

    for item in response["items"]:
        snippet = item["snippet"]["topLevelComment"]["snippet"]
        text = snippet["textDisplay"]
        likes = snippet.get("likeCount", 0)
        author = snippet.get("authorDisplayName", "Anonymous")
        published = snippet.get("publishedAt", None)

        comments.append({
            "comment": text,
            "likes": likes,
            "author": author,
            "publishedAt": published
        })

        if len(comments) >= 400:
            break

    next_page_token = response.get("nextPageToken")

# Convert to DataFrame
df = pd.DataFrame(comments)
df.head(400)
# Out:
#                                                comment  likes  \
# 0         Basketball still sucks. Nothing can help it.      0
# 1                           #8: where is the baby oil?      1
# 2    Man 2017 warriors were so good look at jd gett...      0
# 3            Jack Nicholson’s last one is priceless 😂.      0
# 4    It's genuinely depressing that the most viewed...      0
# ..                                                 ...    ...
# 395                1:24 the best part ahahahahahahahha      0
# 396                             Idiots will be idiots.      0
# 397                        Wish this show was still on      0
# 398                                                😂😂😂      0
# 399                         RHIANNA LINDA DE MAIS ❤️❤️      0
#
#                         author           publishedAt
# 0                     @ptech88  2025-04-30T18:16:30Z
# 1            @danipastrana6838  2025-04-30T10:48:00Z
# 2          @JaiveerSingh-zh2rc  2025-04-30T09:37:20Z
# ...

# %%
# Import required libraries
import pandas as pd
import string
import nltk
from nltk.corpus import stopwords

# Download stopwords (first time only)
nltk.download('stopwords')

# Load English stopwords
stop_words = set(stopwords.words('english'))

# Step 1: Convert all text to lowercase
df['comment_clean'] = df['comment'].str.lower()

# Step 2: Remove punctuation
df['comment_clean'] = df['comment_clean'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))

# Step 3: Remove stopwords
df['comment_clean'] = df['comment_clean'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))

# Step 4: Remove comments with fewer than 3 words
df_clean = df[df['comment_clean'].str.split().str.len() >= 3]

# Step 5: Remove empty or whitespace-only comments
df_clean = df_clean[df_clean['comment_clean'].str.strip().astype(bool)]

# Step 6: Reset index
df_clean.reset_index(drop=True, inplace=True)

# Step 7: Display the first few cleaned comments
df_clean.head(400)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                comment  likes  \
# 0         Basketball still sucks. Nothing can help it.      0
# 1                           #8: where is the baby oil?      1
# 2    Man 2017 warriors were so good look at jd gett...      0
# 3            Jack Nicholson’s last one is priceless 😂.      0
# 4    It's genuinely depressing that the most viewed...      0
# ..                                                 ...    ...
# 286  Spike Lee Mini Afro was on hush mode, Reggie M...      0
# 287                   Rihanna is just different. Damn.      0
# 288                1:24 the best part ahahahahahahahha      0
# 289                        Wish this show was still on      0
# 290                         RHIANNA LINDA DE MAIS ❤️❤️      0
#
#                   author           publishedAt  \
# 0               @ptech88  2025-04-30T18:16:30Z
# ...

# %%
from collections import Counter
import matplotlib.pyplot as plt

# Step 1: Combine all cleaned comments into a single string
all_words = ' '.join(df_clean['comment_clean']).split()

# Step 2: Count word frequencies
word_counts = Counter(all_words)

# Step 3: Select top 15 most common words
most_common = word_counts.most_common(15)
words, counts = zip(*most_common)

# Step 4: Plot bar chart
plt.figure(figsize=(10, 6))
plt.bar(words, counts)
plt.title("Top 15 Most Frequent Words (Video 2)")
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Step 1: Join all cleaned comments into one string
text = ' '.join(df_clean['comment_clean'])

# Step 2: Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Step 3: Display word cloud
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud of Comments (Video 2)")
plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt
import pandas as pd

# Step 1: Prepare text data
text_data = df_clean['comment_clean'].tolist()

# Step 2: Create bigrams
vectorizer = CountVectorizer(ngram_range=(2, 2), stop_words='english')
X = vectorizer.fit_transform(text_data)

# Step 3: Count bigram frequencies
bigrams_freq = X.sum(axis=0)
bigrams = [(word, bigrams_freq[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
bigrams = sorted(bigrams, key=lambda x: x[1], reverse=True)[:15]

# Step 4: Create DataFrame and plot
bigram_df = pd.DataFrame(bigrams, columns=['bigram', 'count'])

plt.figure(figsize=(12, 6))
plt.barh(bigram_df['bigram'], bigram_df['count'], color='skyblue')
plt.xlabel("Frequency")
plt.title("Top 15 Most Frequent Bigrams (Video 2)")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Step 1: Convert publishedAt to datetime
df['publishedAt'] = pd.to_datetime(df['publishedAt'])

# Step 2: Extract only the date
df['date_only'] = df['publishedAt'].dt.date

# Step 3: Count comments per date
comments_by_day = df['date_only'].value_counts().sort_index()

# Step 4: Plot time-series graph
plt.figure(figsize=(10, 5))
comments_by_day.plot(kind='line', marker='o', color='purple')
plt.title("Number of Comments Over Time (Video 2)")
plt.xlabel("Date")
plt.ylabel("Number of Comments")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Step 1: Count number of comments per user
user_counts = df['author'].value_counts().head(10)

# Step 2: Plot bar chart
plt.figure(figsize=(10, 5))
user_counts.plot(kind='bar', color='orange')
plt.title("Top 10 Most Active Users (Video 2)")
plt.xlabel("Username")
plt.ylabel("Number of Comments")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk

# Download VADER lexicon (first time only)
nltk.download('vader_lexicon')

# Initialize analyzer
vader = SentimentIntensityAnalyzer()

# Function to label sentiment based on compound score
def get_sentiment(score):
    if score >= 0.05:
        return 'Positive'
    elif score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

# Apply sentiment scoring
df_clean['compound'] = df_clean['comment_clean'].apply(lambda x: vader.polarity_scores(x)['compound'])
df_clean['sentiment'] = df_clean['compound'].apply(get_sentiment)

# Display sample
df_clean[['comment_clean', 'compound', 'sentiment']].head(400)
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#                                          comment_clean  compound sentiment
# 0                  basketball still sucks nothing help   -0.5801  Negative
# 1                                           8 baby oil    0.0000   Neutral
# 2    man 2017 warriors good look jd getting wide op...    0.4404  Positive
# 3                jack nicholson’s last one priceless 😂    0.0000   Neutral
# 4    genuinely depressing viewed video official nba...   -0.3818  Negative
# ..                                                 ...       ...       ...
# 286  spike lee mini afro hush mode reggie miller se...    0.0000   Neutral
# 287                             rihanna different damn   -0.4019  Negative
# 288                     124 best part ahahahahahahahha    0.6369  Positive
# 289                                    wish show still    0.4019  Positive
# ...

# %%
import matplotlib.pyplot as plt

# Step 1: Calculate sentiment distribution
sentiment_counts = df_clean['sentiment'].value_counts()
sentiment_percentages = sentiment_counts / sentiment_counts.sum() * 100

# Step 2: Pie chart
plt.figure(figsize=(6, 6))
plt.pie(sentiment_percentages, labels=sentiment_percentages.index, autopct='%1.1f%%', colors=['green', 'grey', 'red'])
plt.title("Sentiment Distribution (Video 2)")
plt.show()

# %%
# !pip install --upgrade --force-reinstall gensim
# Out:
# ...
#   Using cached gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# ...
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
#   Using cached scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# ...
#   Using cached smart_open-7.1.0-py3-none-any.whl.metadata (24 kB)
# ...
#   Using cached wrapt-1.17.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Using cached gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# Using cached scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
# Using cached smart_open-7.1.0-py3-none-any.whl (61 kB)
# ...

# %%
import gensim
from gensim import corpora
import nltk
from nltk.corpus import stopwords

# Download stopwords (if needed)
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Step 1: Tokenize and remove stopwords
texts = [
    [word for word in comment.split() if word not in stop_words]
    for comment in df_clean['comment_clean']
]

# Step 2: Create dictionary and corpus
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

# Step 3: Train LDA model
lda_model = gensim.models.LdaModel(
    corpus=corpus,
    id2word=dictionary,
    num_topics=5,
    random_state=42,
    passes=10,
    per_word_topics=True
)

# Step 4: Show topics
topics = lda_model.show_topics(num_words=5, formatted=False)

# Step 5: Display keywords per topic
for i, topic in topics:
    keywords = ", ".join([word for word, prob in topic])
    print(f"Topic {i+1}: {keywords}")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Topic 1: like, jesus, really, mvp, one
# Topic 2: god, damm, rihanna, health, video
# Topic 3: diddy, sit, like, jack, one
# Topic 4: justin, kobe, like, bieber, days
# Topic 5: rock, jack, chris, like, nicholson

# %%
import matplotlib.pyplot as plt

# Number of topics and words per topic
num_topics = 5
topn = 5

# Create subplots
fig, axes = plt.subplots(1, num_topics, figsize=(20, 5), sharey=True)

# Loop through each topic
for i in range(num_topics):
    topic = lda_model.show_topic(i, topn=topn)
    words = [word for word, prob in topic]
    weights = [prob for word, prob in topic]

    axes[i].bar(words, weights, color='skyblue')
    axes[i].set_title(f"Topic {i+1}")
    axes[i].tick_params(axis='x', rotation=45)

# General layout
fig.suptitle("Top 5 Keywords in Each Topic (Video 2)", fontsize=16)
plt.tight_layout()
plt.subplots_adjust(top=0.8)
plt.show()
