# %% [markdown]
# <a href="https://colab.research.google.com/github/Burakgunal4/Web-and-Social-Media-Analysis/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Gerekli kütüphaneler
from googleapiclient.discovery import build
import pandas as pd

# API anahtarı
api_key = "BURAYA_API_KEYİNİ_YAZ"
video_id = "wgVOgGLtPtc"

# YouTube API istemcisi
youtube = build('youtube', 'v3', developerKey=api_key)

comments = []
next_page_token = None

# 200 yorum toplanana kadar devam et
while len(comments) < 200:
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100,
        textFormat="plainText",
        pageToken=next_page_token
    )
    response = request.execute()

    for item in response["items"]:
        comment_snippet = item["snippet"]["topLevelComment"]["snippet"]
        text = comment_snippet["textDisplay"]
        like_count = comment_snippet.get("likeCount", 0)  # likeCount bazı yorumlarda olmayabilir
        comments.append({"comment": text, "likes": like_count})

        if len(comments) >= 200:
            break

    next_page_token = response.get("nextPageToken")

# DataFrame'e aktar
df = pd.DataFrame(comments)

# Beğeniye göre sırala ve ilk 10 yorumu al
top_comments = df.sort_values(by="likes", ascending=False).head(10)

# En çok beğenilen yorumları göster
top_comments.reset_index(drop=True, inplace=True)
top_comments

# %%
# Import necessary libraries
from googleapiclient.discovery import build
import pandas as pd

# Insert your YouTube Data API key here
api_key = "AIzaSyC0dslUAMHingkwPs7AEdRkiHV9SrFLzew"
video_id = "wgVOgGLtPtc"  # ID of the selected NBA video

# Initialize YouTube API client
youtube = build('youtube', 'v3', developerKey=api_key)

# Create a list to store comments
comments = []
next_page_token = None  # For paginating through multiple pages

# Continue retrieving comments until we have 200
while len(comments) < 200:
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100,  # Maximum comments per page is 100
        textFormat="plainText",
        pageToken=next_page_token
    )
    response = request.execute()

    # Extract comment text and like count
    for item in response["items"]:
        comment_snippet = item["snippet"]["topLevelComment"]["snippet"]
        text = comment_snippet["textDisplay"]
        like_count = comment_snippet.get("likeCount", 0)  # If likeCount is missing, use 0
        comments.append({"comment": text, "likes": like_count})

        # Stop if 200 comments have been collected
        if len(comments) >= 200:
            break

    # Update token for next page
    next_page_token = response.get("nextPageToken")

# Convert to a pandas DataFrame
df = pd.DataFrame(comments)

# Sort comments by like count in descending order and get the top 10
top_comments = df.sort_values(by="likes", ascending=False).head(10)

# Reset index and display
top_comments.reset_index(drop=True, inplace=True)
top_comments
# Out:
#                                              comment  likes
# 0                               Who’s in March 2025?    126
# 1  2016 man....\nKobe Bryant's Retirement with th...      9
# 2                                       March 2025 ?      6
# 3  This was the day LeBron became my favorite player      4
# 4  I remember watching this live and busting as s...      4
# 5  To watch that LeBron block live was like a spi...      4
# 6  This is probably the greatest NBA title victor...      4
# 7   2025 still coming back to watch My glorious King      3
# 8                      watching on my lunch break rn      3
# 9  I don't think many will realize what LBJ did h...      3

# %%
# Import necessary libraries
from googleapiclient.discovery import build
import pandas as pd

# Insert your YouTube Data API key here
api_key = "AIzaSyC0dslUAMHingkwPs7AEdRkiHV9SrFLzew"
video_id = "wgVOgGLtPtc"  # ID of the selected NBA video

# Initialize YouTube API client
youtube = build('youtube', 'v3', developerKey=api_key)

# Create a list to store comments
comments = []
next_page_token = None  # For paginating through multiple pages

# Continue retrieving comments until we have 200
while len(comments) < 200:
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100,  # Maximum comments per page is 100
        textFormat="plainText",
        pageToken=next_page_token
    )
    response = request.execute()

    # Extract comment text and like count
    for item in response["items"]:
        comment_snippet = item["snippet"]["topLevelComment"]["snippet"]
        text = comment_snippet["textDisplay"]
        like_count = comment_snippet.get("likeCount", 0)  # If likeCount is missing, use 0
        comments.append({"comment": text, "likes": like_count})

        # Stop if 200 comments have been collected
        if len(comments) >= 200:
            break

    # Update token for next page
    next_page_token = response.get("nextPageToken")

# Convert to a pandas DataFrame
df = pd.DataFrame(comments)

# Sort comments by like count in descending order and get the top 10
top_comments = df.sort_values(by="likes", ascending=False).head(10)

# Reset index and display
top_comments.reset_index(drop=True, inplace=True)
top_comments

display(df.head(200))
display(top_comments)
# Out:
#                                                comment  likes
# 0                                             damn son      0
# 1    Man , score sat at 89 for a while . What inten...      0
# 2                          Cleveland! This is for you!      0
# 3                     Lebron James with the rejection!      0
# 4    Damn if lebron had that dunk at 10 seconds it ...      0
# ..                                                 ...    ...
# 195  nba really gotta have the coaches wear suits a...      2
# 196  Curry throwing that brick up with a little mor...      1
# 197  Most epic thing you’ll ever see, and kyrie irv...      1
# 198       Last real championship that actually counted      0
# 199           The GSW had to get KD to beat this man 😂      2
#
# [200 rows x 2 columns]
#                                              comment  likes
# 0                               Who’s in March 2025?    130
# 1  2016 man....\nKobe Bryant's Retirement with th...      9
# ...

# %%
# Import necessary libraries
from googleapiclient.discovery import build
import pandas as pd

# Insert your YouTube Data API key here
api_key = "AIzaSyC0dslUAMHingkwPs7AEdRkiHV9SrFLzew"
video_id = "wgVOgGLtPtc"  # ID of the selected NBA video

# Initialize YouTube API client
youtube = build('youtube', 'v3', developerKey=api_key)

# Create a list to store comments
comments = []
next_page_token = None  # For paginating through multiple pages

# Continue retrieving comments until we have 200
while len(comments) < 200:
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100,  # Maximum comments per page is 100
        textFormat="plainText",
        pageToken=next_page_token
    )
    response = request.execute()

    # Extract comment text and like count
    for item in response["items"]:
        comment_snippet = item["snippet"]["topLevelComment"]["snippet"]
        text = comment_snippet["textDisplay"]
        like_count = comment_snippet.get("likeCount", 0)  # If likeCount is missing, use 0
        comments.append({"comment": text, "likes": like_count})

        # Stop if 200 comments have been collected
        if len(comments) >= 200:
            break

    # Update token for next page
    next_page_token = response.get("nextPageToken")

# Convert to a pandas DataFrame
df = pd.DataFrame(comments)

# Sort comments by like count in descending order and get the top 10
top_comments = df.sort_values(by="likes", ascending=False).head(10)

# Reset index and display
top_comments.reset_index(drop=True, inplace=True)
top_comments

display(df.head(200))
display(top_comments)
# Out:
#                                                comment  likes
# 0                                             damn son      0
# 1    Man , score sat at 89 for a while . What inten...      0
# 2                          Cleveland! This is for you!      0
# 3                     Lebron James with the rejection!      0
# 4    Damn if lebron had that dunk at 10 seconds it ...      0
# ..                                                 ...    ...
# 195  nba really gotta have the coaches wear suits a...      2
# 196  Curry throwing that brick up with a little mor...      1
# 197  Most epic thing you’ll ever see, and kyrie irv...      1
# 198       Last real championship that actually counted      0
# 199           The GSW had to get KD to beat this man 😂      2
#
# [200 rows x 2 columns]
#                                              comment  likes
# 0                               Who’s in March 2025?    130
# 1  2016 man....\nKobe Bryant's Retirement with th...      9
# ...

# %%
# Import required libraries
import pandas as pd
import string
import nltk
from nltk.corpus import stopwords

# Download stopwords (required for the first run)
nltk.download('stopwords')

# Load English stopwords
stop_words = set(stopwords.words('english'))

# Step 1: Convert all text to lowercase
df['comment_clean'] = df['comment'].str.lower()

# Step 2: Remove punctuation from text
df['comment_clean'] = df['comment_clean'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))

# Step 3: Remove English stopwords
df['comment_clean'] = df['comment_clean'].apply(
    lambda x: ' '.join([word for word in x.split() if word not in stop_words])
)

# Step 4: Remove comments with fewer than 3 words
df_clean = df[df['comment_clean'].str.split().str.len() >= 3]

# Step 5: Remove empty or whitespace-only comments
df_clean = df_clean[df_clean['comment_clean'].str.strip().astype(bool)]

# Preview the first 5 cleaned comments
df_clean.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                              comment  likes  \
# 1  Man , score sat at 89 for a while . What inten...      0
# 3                   Lebron James with the rejection!      0
# 4  Damn if lebron had that dunk at 10 seconds it ...      0
# 5                      3:02 oh block James classic 😂      0
# 6  This is the same year my falcons choked the 28...      0
#
#                                        comment_clean
# 1  man score sat 89 intensity lbj block critical ...
# 3                             lebron james rejection
# 4  damn lebron dunk 10 seconds would greatest dag...
# 5                       302 oh block james classic 😂
# 6  year falcons choked 283 super bowl lead patrio...

# %%
# Import required libraries
import pandas as pd
import string
import nltk
from nltk.corpus import stopwords

# Download stopwords (required for the first run)
nltk.download('stopwords')

# Load English stopwords
stop_words = set(stopwords.words('english'))

# Step 1: Convert all text to lowercase
df['comment_clean'] = df['comment'].str.lower()

# Step 2: Remove punctuation from text
df['comment_clean'] = df['comment_clean'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))

# Step 3: Remove English stopwords
df['comment_clean'] = df['comment_clean'].apply(
    lambda x: ' '.join([word for word in x.split() if word not in stop_words])
)

# Step 4: Remove comments with fewer than 3 words
df_clean = df[df['comment_clean'].str.split().str.len() >= 3]

# Step 5: Remove empty or whitespace-only comments
df_clean = df_clean[df_clean['comment_clean'].str.strip().astype(bool)]

# OPTIONAL Step 6: Reset index for clean DataFrame
df_clean.reset_index(drop=True, inplace=True)

# Step 7: Display all cleaned comments
df_clean  # This will show all cleaned comments in a table
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                comment  likes  \
# 0    Man , score sat at 89 for a while . What inten...      0
# 1                     Lebron James with the rejection!      0
# 2    Damn if lebron had that dunk at 10 seconds it ...      0
# 3                        3:02 oh block James classic 😂      0
# 4    This is the same year my falcons choked the 28...      0
# ..                                                 ...    ...
# 164  nba really gotta have the coaches wear suits a...      2
# 165  Curry throwing that brick up with a little mor...      1
# 166  Most epic thing you’ll ever see, and kyrie irv...      1
# 167       Last real championship that actually counted      0
# 168           The GSW had to get KD to beat this man 😂      2
#
#                                          comment_clean
# ...

# %%
# Import required libraries
import pandas as pd
import string
import nltk
from nltk.corpus import stopwords

# Download stopwords (required for the first run)
nltk.download('stopwords')

# Load English stopwords
stop_words = set(stopwords.words('english'))

# Step 1: Convert all text to lowercase
df['comment_clean'] = df['comment'].str.lower()

# Step 2: Remove punctuation from text
df['comment_clean'] = df['comment_clean'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))

# Step 3: Remove English stopwords
df['comment_clean'] = df['comment_clean'].apply(
    lambda x: ' '.join([word for word in x.split() if word not in stop_words])
)

# Step 4: Remove comments with fewer than 3 words
df_clean = df[df['comment_clean'].str.split().str.len() >= 3]

# Step 5: Remove empty or whitespace-only comments
df_clean = df_clean[df_clean['comment_clean'].str.strip().astype(bool)]

# OPTIONAL Step 6: Reset index for clean DataFrame
df_clean.reset_index(drop=True, inplace=True)

# Step 7: Display all cleaned comments
df_clean  # This will show all cleaned comments in a table


df_clean[['comment_clean']]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                          comment_clean
# 0    man score sat 89 intensity lbj block critical ...
# 1                               lebron james rejection
# 2    damn lebron dunk 10 seconds would greatest dag...
# 3                         302 oh block james classic 😂
# 4    year falcons choked 283 super bowl lead patrio...
# ..                                                 ...
# 164                nba really gotta coaches wear suits
# 165  curry throwing brick little minute left dumb c...
# 166  epic thing you’ll ever see kyrie irving foreve...
# 167            last real championship actually counted
# 168                              gsw get kd beat man 😂
#
# [169 rows x 1 columns]
